# %% [markdown]
# <a href="https://colab.research.google.com/github/victoricoma/am-turma5/blob/main/am_turma5_aula0804.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
