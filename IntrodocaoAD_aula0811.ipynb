# %% [markdown]
# <a href="https://colab.research.google.com/github/victoricoma/am-turma5/blob/main/IntrodocaoAD_aula0811.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline de Analise de Dados [Credit_Data]

# %% [markdown]
# ## Importação de Bibliotecas
#
# *   Pandas
# *   Numpy
# *   MatPlotLib
# *   SeaBorn

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Carregamento dos Dados da Base

# %%
base_credit = pd.read_csv('/content/drive/MyDrive/am-t6/credit_data.csv')

# %%
base_credit
# Out:
#       clientid        income        age         loan  default
# 0            1  66155.925095  59.017015  8106.532131        0
# 1            2  34415.153966  48.117153  6564.745018        0
# 2            3  57317.170063  63.108049  8020.953296        0
# 3            4  42709.534201  45.751972  6103.642260        0
# 4            5  66952.688845  18.584336  8770.099235        1
# ...        ...           ...        ...          ...      ...
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0
#
# [2000 rows x 5 columns]

# %%
base_credit.describe()
# Out:
#           clientid        income          age          loan      default
# count  2000.000000   2000.000000  1997.000000   2000.000000  2000.000000
# mean   1000.500000  45331.600018    40.807559   4444.369695     0.141500
# std     577.494589  14326.327119    13.624469   3045.410024     0.348624
# min       1.000000  20014.489470   -52.423280      1.377630     0.000000
# 25%     500.750000  32796.459717    28.990415   1939.708847     0.000000
# 50%    1000.500000  45789.117313    41.317159   3974.719419     0.000000
# 75%    1500.250000  57791.281668    52.587040   6432.410625     0.000000
# max    2000.000000  69995.685578    63.971796  13766.051239     1.000000

# %% [markdown]
# ## Análise de Possíveis Anomalias

# %%
base_credit.loc[base_credit['age'] < 18]
# Out:
#     clientid        income        age         loan  default
# 15        16  50501.726689 -28.218361  3977.287432        0
# 21        22  32197.620701 -52.423280  4244.057136        0
# 26        27  63287.038908 -36.496976  9595.286289        0

# %%
base_cre
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1941/2155755030.py in <cell line: 0>()
# ----> 1 base_cre
#
# NameError: name 'base_cre' is not defined

# %% [markdown]
# ## Análise de Nulidade

# %%
base_credit.isnull().sum()

# %% [markdown]
# ## Correção de Anomalias
